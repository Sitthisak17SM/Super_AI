# %% [markdown]
# <a href="https://colab.research.google.com/github/Sitthisak17SM/Super_AI/blob/main/hak3_600817_%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A8%E0%B8%B1%E0%B8%81%E0%B8%94%E0%B8%B4%E0%B9%8C_%E0%B8%AA%E0%B8%B5%E0%B8%AB%E0%B8%A1%E0%B8%B7%E0%B9%88%E0%B8%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FahMai RAG
#
#
# **Sections:**
# - **Section 0:** Setup & LLM Test
# - **Section 1:** Dense Retrieval (MiniLM)
# - **Section 2:** Sparse Retrieval (BM25)
# - **Section 3:** Hybrid Retrieval (RRF)

# %%
# !unzip /content/super-ai-engineer-s-6-fah-mai-rag-challenge-level-1.zip
# Out:
# Archive:  /content/super-ai-engineer-s-6-fah-mai-rag-challenge-level-1.zip
#   inflating: data/knowledge_base/policies/cancellation_policy.md
#   inflating: data/knowledge_base/policies/membership_points_policy.md
#   inflating: data/knowledge_base/policies/return_policy.md
#   inflating: data/knowledge_base/policies/shipping_policy.md
#   inflating: data/knowledge_base/policies/warranty_policy.md
#   inflating: data/knowledge_base/products/AW-MN-001_arcwave_proview_27_4k.md
#   inflating: data/knowledge_base/products/AW-SK-001_arcwave_soundpillar_300.md
#   inflating: data/knowledge_base/products/DN-DT-001_daonuea_tower_x10.md
#   inflating: data/knowledge_base/products/DN-DT-002_daonuea_tower_x10_max.md
#   inflating: data/knowledge_base/products/DN-DT-003_daonuea_mini_pc_m1.md
#   inflating: data/knowledge_base/products/DN-DT-004_daonuea_all_in_one_27.md
#   inflating: data/knowledge_base/products/DN-DT-005_daonuea_all_in_one_24.md
#   inflating: data/knowledge_base/products/DN-LT-001_daonuea_airbook_15.md
#   inflating: data/knowledge_base/products/DN-LT-002_daonuea_airbook_14.md
#   inflating: data/knowledge_base/products/DN-LT-003_daonuea_airbook_14_8gb.md
#   inflating: data/knowledge_base/products/DN-LT-004_daonuea_probook_16.md
#   inflating: data/knowledge_base/products/DN-LT-005_daonuea_probook_14.md
#   inflating: data/knowledge_base/products/DN-LT-006_daonuea_probook_14_max.md
#   inflating: data/knowledge_base/products/DN-LT-007_daonuea_stormbook_g7.md
#   inflating: data/knowledge_base/products/DN-LT-008_daonuea_stormbook_g5.md
#   inflating: data/knowledge_base/products/DN-LT-009_daonuea_stormbook_g5_2024.md
#   inflating: data/knowledge_base/products/DN-LT-010_daonuea_stormbook_g9_titan.md
#   inflating: data/knowledge_base/products/DN-LT-011_daonuea_studybook_14.md
#   inflating: data/knowledge_base/products/DN-LT-012_daonuea_studybook_14_plus.md
#   inflating: data/knowledge_base/products/DN-LT-013_daonuea_studybook_11.md
#   inflating: data/knowledge_base/products/DN-LT-014_daonuea_creatorbook_16_oled.md
#   inflating: data/knowledge_base/products/DN-LT-015_daonuea_creatorbook_14.md
#   inflating: data/knowledge_base/products/DN-LT-016_daonuea_flexbook_360.md
#   inflating: data/knowledge_base/products/DN-LT-017_daonuea_flexbook_detach.md
#   inflating: data/knowledge_base/products/DN-LT-018_daonuea_flexbook_detach_keyboard_bundle.md
#   inflating: data/knowledge_base/products/JC-CH-001_judchuam_charger_67w_usbc.md
#   inflating: data/knowledge_base/products/JC-CH-002_judchuam_charger_100w_usbc_dual.md
#   inflating: data/knowledge_base/products/JC-CH-003_judchuam_charger_30w_usbc.md
#   inflating: data/knowledge_base/products/JC-CH-004_judchuam_charger_20w_usba.md
#   inflating: data/knowledge_base/products/JC-CH-005_judchuam_qipad_15.md
#   inflating: data/knowledge_base/products/JC-CH-006_judchuam_cable_usbc_to_usbc_1m.md
#   inflating: data/knowledge_base/products/JC-CH-007_judchuam_cable_usbc_to_usbc_2m.md
#   inflating: data/knowledge_base/products/JC-CH-008_judchuam_cable_usbc_to_lightning_1m.md
#   inflating: data/knowledge_base/products/JC-CS-001_judchuam_case_clear_x9_pro.md
#   inflating: data/knowledge_base/products/JC-CS-002_judchuam_case_clear_x9.md
#   inflating: data/knowledge_base/products/JC-CS-003_judchuam_case_rugged_x9_pro.md
#   inflating: data/knowledge_base/products/JC-CS-004_judchuam_film_glass_x9_pro_2pack.md
#   inflating: data/knowledge_base/products/JC-CS-005_judchuam_keyboard_case_tab_s9_pro.md
#   inflating: data/knowledge_base/products/JC-CS-006_judchuam_saifah_pen_gen2.md
#   inflating: data/knowledge_base/products/JC-HB-001_judchuam_hub_usbc_7in1.md
#   inflating: data/knowledge_base/products/JC-HB-002_judchuam_hub_usbc_4in1.md
#   inflating: data/knowledge_base/products/JC-HB-003_judchuam_dock_pro.md
#   inflating: data/knowledge_base/products/JC-HB-004_judchuam_dock_airbook_edition.md
#   inflating: data/knowledge_base/products/KS-EB-001_kluensiang_buds_z5_pro.md
#   inflating: data/knowledge_base/products/KS-EB-002_kluensiang_buds_z5.md
#   inflating: data/knowledge_base/products/KS-EB-003_kluensiang_buds_z3.md
#   inflating: data/knowledge_base/products/KS-EB-004_kluensiang_buds_sport_x.md
#   inflating: data/knowledge_base/products/KS-EB-005_kluensiang_buds_sport_lite.md
#   inflating: data/knowledge_base/products/KS-EB-006_kluensiang_buds_z1.md
#   inflating: data/knowledge_base/products/KS-EB-007_kluensiang_buds_open_ring.md
#   inflating: data/knowledge_base/products/KS-EB-008_kluensiang_buds_z5_pro_gold_limited.md
#   inflating: data/knowledge_base/products/KS-HP-001_kluensiang_headpro_x1.md
#   inflating: data/knowledge_base/products/KS-HP-002_kluensiang_headpro_x1_se.md
#   inflating: data/knowledge_base/products/KS-HP-003_kluensiang_headon_700.md
#   inflating: data/knowledge_base/products/KS-HP-004_kluensiang_headon_500.md
#   inflating: data/knowledge_base/products/KS-HP-005_kluensiang_headon_300.md
#   inflating: data/knowledge_base/products/KS-HP-006_kluensiang_headon_300_fahmai_edition.md
#   inflating: data/knowledge_base/products/KS-HP-007_kluensiang_studiopro_m1.md
#   inflating: data/knowledge_base/products/KS-HP-008_kluensiang_gamestorm_h1.md
#   inflating: data/knowledge_base/products/KS-SK-001_kluensiang_soundbar_pro_500.md
#   inflating: data/knowledge_base/products/KS-SK-002_kluensiang_soundbar_300.md
#   inflating: data/knowledge_base/products/KS-SK-003_kluensiang_boombox_x.md
#   inflating: data/knowledge_base/products/KS-SK-004_kluensiang_go_mini.md
#   inflating: data/knowledge_base/products/KS-SK-005_kluensiang_go_mini_pack_2.md
#   inflating: data/knowledge_base/products/KS-SK-006_kluensiang_homepod_one.md
#   inflating: data/knowledge_base/products/NT-EB-001_novatech_novabuds_pro.md
#   inflating: data/knowledge_base/products/NT-KB-001_novatech_keyboard_k7.md
#   inflating: data/knowledge_base/products/NT-LT-001_novatech_slimbook_14.md
#   inflating: data/knowledge_base/products/NT-MS-001_novatech_mouse_m3.md
#   inflating: data/knowledge_base/products/PG-CH-001_pulsegear_chargepad_15w.md
#   inflating: data/knowledge_base/products/PG-PB-001_pulsegear_powerbank_20000mah.md
#   inflating: data/knowledge_base/products/PG-PB-002_pulsegear_powerbank_30000mah.md
#   inflating: data/knowledge_base/products/SF-SP-001_saifah_phone_x9_pro_max.md
#   inflating: data/knowledge_base/products/SF-SP-002_saifah_phone_x9_pro.md
#   inflating: data/knowledge_base/products/SF-SP-003_saifah_phone_x9.md
#   inflating: data/knowledge_base/products/SF-SP-004_saifah_phone_v7.md
#   inflating: data/knowledge_base/products/SF-SP-005_saifah_phone_v7_lite.md
#   inflating: data/knowledge_base/products/SF-SP-006_saifah_phone_v5_2024.md
#   inflating: data/knowledge_base/products/SF-SP-007_saifah_phone_lite_5.md
#   inflating: data/knowledge_base/products/SF-SP-008_saifah_phone_lite_5g.md
#   inflating: data/knowledge_base/products/SF-SP-009_saifah_phone_lite_3.md
#   inflating: data/knowledge_base/products/SF-SP-010_saifah_phone_x9_fe.md
#   inflating: data/knowledge_base/products/SF-SP-011_saifah_phone_duopad.md
#   inflating: data/knowledge_base/products/SF-SP-012_saifah_phone_pocketmini.md
#   inflating: data/knowledge_base/products/SF-SP-013_saifah_phone_kid_safe.md
#   inflating: data/knowledge_base/products/SF-SP-014_saifah_phone_senior_plus.md
#   inflating: data/knowledge_base/products/SF-SP-015_saifah_phone_rugged_r1.md
#   inflating: data/knowledge_base/products/SF-TB-001_saifah_tab_s9_pro.md
#   inflating: data/knowledge_base/products/SF-TB-002_saifah_tab_s9.md
#   inflating: data/knowledge_base/products/SF-TB-003_saifah_tab_a5.md
#   inflating: data/knowledge_base/products/SF-TB-004_saifah_tab_a5_wifi.md
#   inflating: data/knowledge_base/products/SF-TB-005_saifah_tab_mini_7.md
#   inflating: data/knowledge_base/products/SF-TB-006_saifah_tab_kid.md
#   inflating: data/knowledge_base/products/SF-TB-007_saifah_tab_draw_pro.md
#   inflating: data/knowledge_base/products/SF-TB-008_saifah_tab_s8_pro.md
#   inflating: data/knowledge_base/products/WK-FT-001_wongkhojon_band_8.md
#   inflating: data/knowledge_base/products/WK-FT-002_wongkhojon_band_8_pro.md
#   inflating: data/knowledge_base/products/WK-FT-003_wongkhojon_band_7.md
#   inflating: data/knowledge_base/products/WK-FT-004_wongkhojon_ring_1.md
#   inflating: data/knowledge_base/products/WK-SW-001_wongkhojon_watch_s3_ultra.md
#   inflating: data/knowledge_base/products/WK-SW-002_wongkhojon_watch_s3_pro.md
#   inflating: data/knowledge_base/products/WK-SW-003_wongkhojon_watch_s3.md
#   inflating: data/knowledge_base/products/WK-SW-004_wongkhojon_watch_s3_se.md
#   inflating: data/knowledge_base/products/WK-SW-005_wongkhojon_watch_sport_g1.md
#   inflating: data/knowledge_base/products/WK-SW-006_wongkhojon_watch_classic_c1.md
#   inflating: data/knowledge_base/products/WK-SW-007_wongkhojon_watch_kid_k1.md
#   inflating: data/knowledge_base/products/WK-SW-008_wongkhojon_watch_s2_pro.md
#   inflating: data/knowledge_base/products/ZB-RAM-001_zenbyte_ddr5_ram_16gb.md
#   inflating: data/knowledge_base/products/ZB-SSD-001_zenbyte_ssd_nvme_1tb.md
#   inflating: data/knowledge_base/products/ZB-SSD-002_zenbyte_ssd_nvme_2tb.md
#   inflating: data/knowledge_base/store_info/about_fahmai.md
#   inflating: data/knowledge_base/store_info/buying_guide_smartphones_2569.md
#   inflating: data/knowledge_base/store_info/general_faq.md
#   inflating: data/questions.csv
#   inflating: data/sample_submission.csv

# %%
N_QUESTIONS = 100
DATA_DIR = "/content/data"
KB_DIR = f"{DATA_DIR}/knowledge_base"

# %%
KB_DIR
# Out:
# '/content/data/knowledge_base'

# %% [markdown]
# ---
# ## Section 0: Setup & LLM Test
#
# First, install dependencies and test the ThaiLLM API — **without** any retrieval. This shows why RAG is needed.
#
# ThaiLLM website: https://playground.thaillm.or.th/chat/

# %%
# !pip install -q sentence-transformers pythainlp rank-bm25 requests python-dotenv

# %%
import os, csv, re, time, requests
import numpy as np
from pathlib import Path
from google.colab import userdata

THAILLM_API_KEY = userdata.get('ThaiLLM')

# %%
def ask_llm(messages, model="OpenThaiGPT", max_retries=5):
    """Call ThaiLLM API with retry and rate-limit handling.

    Available models: typhoon, openthaigpt, pathumma, kbtg
    """
    url = f"http://thaillm.or.th/api/openthaigpt/v1/chat/completions"
    headers = {"Content-Type": "application/json", "apikey": THAILLM_API_KEY}
    payload = {
        "model": "/model",
        "messages": messages,
        "max_tokens": 2048,
        "temperature": 0.0,
    }

    for attempt in range(max_retries):
        try:
            resp = requests.post(url, headers=headers, json=payload, timeout=120)

            # Rate limit — wait and retry
            if resp.status_code == 429:
                wait = min(2 ** attempt, 30)
                print(f"  Rate limited, waiting {wait}s...")
                time.sleep(wait)
                continue

            resp.raise_for_status()
            return resp.json()["choices"][0]["message"]["content"].strip()

        except requests.exceptions.RequestException as e:
            wait = 2 ** attempt
            print(f"  Error: {e}, retrying in {wait}s...")
            time.sleep(wait)

    return None


def parse_answer(text):
    """Extract answer number from LLM response."""
    if text is None:
        return None
    # Remove any <think>...</think> blocks (some models do chain-of-thought)
    clean = re.sub(r"<think>.*?</think>", "", text, flags=re.DOTALL).strip()
    # Look for ANSWER: X pattern
    m = re.search(r"ANSWER:\s*(\d+)", clean)
    if m:
        return int(m.group(1))
    # Fallback: first standalone number 1-10
    for d in re.findall(r"\b(\d{1,2})\b", clean):
        if 1 <= int(d) <= 10:
            return int(d)
    return None

# %% [markdown]
# ### Test the LLM without RAG
#
# Let's ask a FahMai-specific question *without* any context. The LLM shouldn't know the answer.

# %%
# Ask without context — LLM has no idea about FahMai's products
response = ask_llm([
    {"role": "user", "content": "Watch S3 Ultra กันน้ำได้กี่ ATM ครับ?"}
])
print("LLM response (no context):", response)
print("\n→ The LLM doesn't know FahMai-specific facts. We need RAG!")

# %% [markdown]
# ### Load Questions

# %%
questions = []
with open(f"{DATA_DIR}/questions.csv", encoding="utf-8") as f:
    for row in csv.DictReader(f):
        choices = {str(i): row[f"choice_{i}"] for i in range(1, 11)}
        questions.append({"id": int(row["id"]), "question": row["question"], "choices": choices})

print(f"Loaded {len(questions)} questions, using first {N_QUESTIONS} for this run")
print(f"\nExample — Q1: {questions[0]['question']}")
for k, v in questions[0]["choices"].items():
    print(f"  {k}. {v}")

# %% [markdown]
# ---
# ## Section 1: Dense Retrieval (MiniLM)
#
# **Dense retrieval** converts text into vectors (embeddings) and finds relevant chunks by cosine similarity.
#
# The pipeline: **Load docs → Chunk → Embed → Retrieve → Generate**
#
# ### 1.1 Load Knowledge Base

# %%
kb_dir = Path(KB_DIR)
documents = []
for fp in sorted(kb_dir.rglob("*.md")):
    text = fp.read_text(encoding="utf-8")
    documents.append({"path": str(fp.relative_to(kb_dir)), "text": text})

print(f"Loaded {len(documents)} documents")
print(f"  products/: {sum(1 for d in documents if 'products/' in d['path'])}")
print(f"  policies/: {sum(1 for d in documents if 'policies/' in d['path'])}")
print(f"  store_info/: {sum(1 for d in documents if 'store_info/' in d['path'])}")

# Preview one document
print(f"\n--- Sample: {documents[0]['path']} ---")
print(documents[0]["text"][:500])

# %% [markdown]
# ### 1.2 Chunking

# %%
# !pip install langchain-text-splitters

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter, RecursiveCharacterTextSplitter

# 1. กำหนดโครงสร้าง Markdown ที่เราต้องการให้มันใช้เป็นจุดตัด (Split)
headers_to_split_on = [
    ("#", "Header 1"),    # เช่น ชื่อสินค้า หรือ ชื่อหมวดหลัก
    ("##", "Header 2"),   # เช่น สเปก, การรับประกัน
    ("###", "Header 3"),  # เช่น รายละเอียดขนาดย่อย
]

# สร้างตัวตัดเอกสารตามหัวข้อ Markdown
markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

# 2. (แผนสำรอง) หากข้อมูลใต้หัวข้อนั้นๆ ยังยาวเกินไป เราจะสับย่อยอีกรอบให้ขนาดไม่เกินหน้าต่างของ LLM
chunk_size = 1000
chunk_overlap = 150
text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

chunks = []

# วนลูปอ่านเอกสารทีละไฟล์
for doc in documents:
    # ตัดเอกสารรอบแรกตามหัวข้อ Markdown (จะได้ข้อความพร้อม Metadata ว่ามาจากหัวข้อไหน)
    md_header_splits = markdown_splitter.split_text(doc["text"])

    # ตัดเอกสารรอบสอง ถ้าย่อหน้านั้นยาวเกิน chunk_size
    final_splits = text_splitter.split_documents(md_header_splits)

    for split in final_splits:
        # --- การทำ Context-Enriched Chunking (เสริมบริบท) ---
        # สมมติ metadata คือ {'Header 1': 'Watch S3 Ultra', 'Header 2': 'การกันน้ำ'}
        # เราจะจับมาต่อกันเป็น "Watch S3 Ultra > การกันน้ำ"
        header_context = " > ".join(split.metadata.values()) if split.metadata else "เนื้อหาทั่วไป"

        # ✨ จุดสำคัญ: แปะ "ชื่อไฟล์อ้างอิง" และ "ลำดับหัวข้อ" ไว้ส่วนบนสุดของข้อความเสมอ!
        # วิธีนี้จะแก้ปัญหา "Chunk กำพร้า" (LLM อ่านแล้วไม่รู้ว่ากำลังพูดถึงสินค้าตัวไหน)
        enriched_text = f"ไฟล์อ้างอิง: {doc['path']}\nหัวข้อที่เกี่ยวข้อง: {header_context}\n---\n{split.page_content}"

        chunks.append({
            "text": enriched_text,
            "source": doc["path"],
            "metadata": split.metadata # เก็บ metadata ไว้ เผื่อนำไปทำ Filtering ใน RAG ต่อได้
        })

print(f"Created {len(chunks)} specialized chunks from {len(documents)} documents")
print(f"\n--- Sample chunk ---")
print(f"Source: {chunks[0]['source']}")
print(f"Metadata: {chunks[0]['metadata']}")
print("Text:\n" + chunks[0]["text"][:300])

# %% [markdown]
# ### 1.3 Embedding

# %%
from sentence_transformers import SentenceTransformer, CrossEncoder
import torch

# 1. โหลดโมเดล BAAI/bge-m3
# แนะนำให้ระบุ device เป็น 'cuda' หากรันบน Colab ที่มี GPU เพื่อให้ทำงานเร็วขึ้น
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Loading BGE-M3 model on: {device}")

embed_model = SentenceTransformer("BAAI/bge-m3", device=device)
# ✨ เพิ่มใหม่
cross_encoder = CrossEncoder("BAAI/bge-reranker-v2-m3", device=device)
print("Models loaded!")
# 2. ดึงเฉพาะส่วนข้อความ (Text) ออกมาจาก List ของ Chunks
chunk_texts = [c["text"] for c in chunks]

# 3. สร้าง Embeddings (แปลงข้อความเป็นเวกเตอร์)
print(f"Encoding {len(chunk_texts)} chunks. This might take a moment...")
chunk_embeddings = embed_model.encode(
    chunk_texts,
    batch_size=16,               # bge-m3 ตัวใหญ่กว่า แนะนำให้ลด batch_size ลงจาก 64 เหลือ 16 หรือ 32 เพื่อป้องกัน GPU RAM เต็ม
    show_progress_bar=True,
    normalize_embeddings=True    # สำคัญมากสำหรับการทำ Cosine Similarity ใน RAG
)

print(f"\nChunk embeddings shape: {chunk_embeddings.shape}")
# ผลลัพธ์ควรจะได้เป็น (n_chunks, 1024)
# สังเกตว่ามิติข้อมูลจะใหญ่กว่า MiniLM (384) ซึ่งเก็บรายละเอียดความหมายได้มากกว่า

# %% [markdown]
# ### 1.4 Retrieve

# %%
# !pip install rank-bm25 pythainlp
# Out:
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: pythainlp in /usr/local/lib/python3.12/dist-packages (5.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rank-bm25) (2.0.2)

# %%
import numpy as np
from rank_bm25 import BM25Okapi
from pythainlp.tokenize import word_tokenize

# ==========================================
# ส่วนที่ 1: สร้างฐานข้อมูลสำหรับค้นหาด้วยคีย์เวิร์ด (BM25 Index)
# (ขั้นตอนนี้รันแค่ครั้งเดียวตอนเตรียมข้อมูล)
# ==========================================
print("Tokenizing chunks for BM25...")
# เราต้องใช้ PyThaiNLP ตัดคำภาษาไทยใน Chunks เพื่อให้ BM25 นับคำได้แม่นยำ
tokenized_chunks = [word_tokenize(chunk["text"], engine="newmm") for chunk in chunks]
bm25 = BM25Okapi(tokenized_chunks)
print("BM25 Index created successfully!")

# ==========================================
# ส่วนที่ 2: ฟังก์ชัน Hybrid Search ด้วย RRF
# ==========================================
TOP_K = 10

def hybrid_retrieve(query, chunk_embs, k=TOP_K, rrf_k=60):
    """ค้นหาด้วย Vector และ BM25 แล้วนำมารวมคะแนนกันด้วย RRF"""

    # --- ฝั่งที่ 1: Dense Retrieval (หาด้วย Vector ความหมาย) ---
    q_emb = embed_model.encode([query], normalize_embeddings=True)
    dense_scores = np.dot(chunk_embs, q_emb.T).flatten()
    # จัดอันดับเอกสารทั้งหมดตามคะแนน Vector
    dense_ranked_indices = np.argsort(dense_scores)[::-1]

    # --- ฝั่งที่ 2: Sparse Retrieval (หาด้วย BM25 คีย์เวิร์ด) ---
    tokenized_query = word_tokenize(query, engine="newmm")
    bm25_scores = bm25.get_scores(tokenized_query)
    # จัดอันดับเอกสารทั้งหมดตามคะแนน BM25
    sparse_ranked_indices = np.argsort(bm25_scores)[::-1]

    # --- ขั้นตอนที่ 3: รวมคะแนนด้วยสมการ RRF (Reciprocal Rank Fusion) ---
    # เอกสารไหนที่ได้อันดับดี (Rank ต้นๆ) จากทั้ง 2 ฝั่ง จะได้คะแนน RRF สูง
    rrf_scores = np.zeros(len(chunks))

    # ให้คะแนนจากฝั่ง Vector
    for rank, doc_idx in enumerate(dense_ranked_indices):
        rrf_scores[doc_idx] += 1.0 / (rrf_k + rank + 1) # +1 เพราะ rank ใน Python เริ่มจาก 0

    # ให้คะแนนจากฝั่ง BM25
    for rank, doc_idx in enumerate(sparse_ranked_indices):
        rrf_scores[doc_idx] += 1.0 / (rrf_k + rank + 1)

    # --- สรุปผล: ดึง Top K ที่คะแนนรวมสูงสุด ---
    final_top_indices = np.argsort(rrf_scores)[::-1][:k]
    final_scores = rrf_scores[final_top_indices]

    return final_top_indices, final_scores



# ==========================================
# ส่วนที่ 3: ทดสอบการค้นหา
# ==========================================
# สมมติว่าเอาคำถามข้อแรกจากไฟล์ CSV มาทดสอบ
q = questions[0]
print(f"คำถาม: {q['question']}\n")

# เรียกใช้ฟังก์ชัน hybrid_retrieve ตัวใหม่
idx, scores = hybrid_retrieve(q["question"], chunk_embeddings)

for rank, (i, s) in enumerate(zip(idx, scores), 1):
    print(f"อันดับ {rank} (คะแนน RRF = {s:.4f}) | ไฟล์อ้างอิง: [{chunks[i]['source']}]")
    print(f"เนื้อหา: {chunks[i]['text'][:200]}...")
    print("-" * 60)
# Out:
# Tokenizing chunks for BM25...
# BM25 Index created successfully!
# คำถาม: Watch S3 Ultra กันน้ำได้กี่ ATM ครับ
#
# อันดับ 1 (คะแนน RRF = 0.0325) | ไฟล์อ้างอิง: [products/WK-SW-001_wongkhojon_watch_s3_ultra.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้
# ---
# **Q: Watch S3 Ultra ต่างจาก W...
# ------------------------------------------------------------
# อันดับ 2 (คะแนน RRF = 0.0320) | ไฟล์อ้างอิง: [products/WK-SW-002_wongkhojon_watch_s3_pro.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-002_wongkhojon_watch_s3_pro.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Pro (WongKhoJon Watch S3 Pro) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้
# ---
# **Q: Watch S3 Pro มี ECG ไหมครับ? ต...
# ------------------------------------------------------------
# อันดับ 3 (คะแนน RRF = 0.0318) | ไฟล์อ้างอิง: [products/WK-SW-001_wongkhojon_watch_s3_ultra.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > รายละเอียดสินค้า
# ---
# เมื่อกีฬาและเทคโนโลยีมาบรรจบกัน วงโคจร Watch ...
# ------------------------------------------------------------
# อันดับ 4 (คะแนน RRF = 0.0298) | ไฟล์อ้างอิง: [products/WK-SW-001_wongkhojon_watch_s3_ultra.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้
# ---
# **Q: GPS Dual-Band แตกต่างจาก...
# ------------------------------------------------------------
# อันดับ 5 (คะแนน RRF = 0.0294) | ไฟล์อ้างอิง: [products/WK-SW-003_wongkhojon_watch_s3.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-003_wongkhojon_watch_s3.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 (WongKhoJon Watch S3) > รายละเอียดสินค้า
# ---
# สำหรับผู้ที่ต้องการสมาร์ทวอทช์ที่ครบเครื่องในงบประมาณระดับกลาง ...
# ------------------------------------------------------------
# อันดับ 6 (คะแนน RRF = 0.0292) | ไฟล์อ้างอิง: [products/WK-SW-001_wongkhojon_watch_s3_ultra.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > โปรโมชันปัจจุบัน
# ---
# **ผ่อน 0% นาน 6 เดือน** ผ่านบัตรเครดิตที่ร่วม...
# ------------------------------------------------------------
# อันดับ 7 (คะแนน RRF = 0.0289) | ไฟล์อ้างอิง: [products/WK-SW-003_wongkhojon_watch_s3.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-003_wongkhojon_watch_s3.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 (WongKhoJon Watch S3) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้
# ---
# **Q: Watch S3 กับ Watch S3 Pro ต่างกันยังไงครับ...
# ------------------------------------------------------------
# อันดับ 8 (คะแนน RRF = 0.0285) | ไฟล์อ้างอิง: [products/WK-SW-001_wongkhojon_watch_s3_ultra.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > สเปคสินค้า
# ---
# | รายการ | รายละเอียด |
# |--------|-----------|
# | หน...
# ------------------------------------------------------------
# อันดับ 9 (คะแนน RRF = 0.0284) | ไฟล์อ้างอิง: [products/WK-SW-002_wongkhojon_watch_s3_pro.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-002_wongkhojon_watch_s3_pro.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Pro (WongKhoJon Watch S3 Pro) > รายละเอียดสินค้า
# ---
# วงโคจร Watch S3 Pro คือสมาร์ทวอทช์ระดับกลางบนที่ไม่...
# ------------------------------------------------------------
# อันดับ 10 (คะแนน RRF = 0.0284) | ไฟล์อ้างอิง: [products/WK-SW-001_wongkhojon_watch_s3_ultra.md]
# เนื้อหา: ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md
# หัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > ความเข้ากันได้
# ---
# - **สมาร์ทโฟน:** FahMai OS 13 ขึ้นไป และ Androi...
# ------------------------------------------------------------

# %% [markdown]
# ### 1.5 Generate Answer
#
# Send the retrieved context + question + choices to the LLM and parse the answer.

# %%
# ==========================================
# 1.5 Generate Answer (อัปเกรด Prompt ขั้นสุดยอด)
# ==========================================

# 1. กำหนด System Prompt ให้มี Persona ชัดเจน และมีกฎเหล็ก (System Guardrails)
SYSTEM_PROMPT = """คุณคือ AI ผู้ช่วยบริการลูกค้าของร้าน 'ฟ้าใหม่' (FahMai) ระดับมืออาชีพ
หน้าที่ของคุณคือตอบคำถามของลูกค้าโดยใช้ *ข้อมูลอ้างอิงที่กำหนดให้เท่านั้น* ห้ามใช้ความรู้ส่วนตัวตอบเด็ดขาด

กฎการตอบคำถาม:
1. อ่านและวิเคราะห์ข้อมูลอ้างอิงอย่างละเอียดเพื่อหาตัวเลือกที่ถูกต้องที่สุด
2. หากในข้อมูลอ้างอิง "ไม่มีคำตอบที่ชัดเจน" ให้เลือกตัวเลือก 'ไม่มีข้อมูลนี้ในฐานข้อมูล' เสมอ
3. หากคำถาม "ไม่เกี่ยวข้องกับร้านฟ้าใหม่หรือสินค้าในร้าน" ให้เลือกตัวเลือก 'คำถามนี้ไม่เกี่ยวข้องกับฐานข้อมูลสินค้า' เสมอ
4. ให้คุณอธิบายเหตุผลสั้นๆ ก่อนตอบ
และบรรทัดสุดท้าย **ต้อง**
ขั้นตอน:
   1. ระบุว่าคำถามถามเรื่องอะไร
   2. หาข้อมูลที่ตรงกันใน Context
   3. ตรวจสอบทุกตัวเลือกก่อนสรุป 'ANSWER: X' เท่านั้น (โดย X คือหมายเลขตัวเลือก 1-10)"""

def build_rag_prompt(question, choices, retrieved_chunks):
    """สร้างโครงสร้าง Prompt ให้ AI อ่านง่ายที่สุด"""

    # จัดรูปแบบข้อมูลอ้างอิงให้ชัดเจน
    context = "\n\n".join(
        f"[ข้อมูลอ้างอิงชิ้นที่ {i+1}]\n{c['text']}"
        for i, c in enumerate(retrieved_chunks)
    )

    # จัดรูปแบบตัวเลือก
    choices_text = "\n".join(f"ตัวเลือกที่ {k}: {v}" for k, v in choices.items())

    return f"""ข้อมูลอ้างอิง:
{context}

---
คำถามจากลูกค้า: {question}

ตัวเลือกที่มี:
{choices_text}

กรุณาวิเคราะห์ข้อมูลอ้างอิงเพื่อตอบคำถามลูกค้า (อย่าลืมสรุปคำตอบในรูปแบบ ANSWER: X ในบรรทัดสุดท้าย):"""

# ==========================================
# ทดสอบรันกับคำถามข้อที่ 1
# ==========================================
q = questions[0]

# ✨ เปลี่ยนมาใช้ hybrid_retrieve แทนของเดิมเพื่อให้หาข้อมูลเป๊ะขึ้น
idx, scores = hybrid_retrieve(q["question"], chunk_embeddings, k=10)
retrieved = [chunks[i] for i in idx]

prompt = build_rag_prompt(q["question"], q["choices"], retrieved)

print(f"กำลังส่งคำถามไปให้ LLM คิด... (คำถาม: {q['question']})\n")

# เรียกใช้งาน LLM
raw = ask_llm([
    {"role": "system", "content": SYSTEM_PROMPT},
    {"role": "user", "content": prompt},
])

answer = parse_answer(raw)

print("="*50)
print(f"LLM ตอบกลับมาว่า (Raw Output):\n{raw}")
print("="*50)
print(f"ผลลัพธ์ที่สกัดได้ (Parsed answer): {answer}")

# %%
retrieved
# Out:
# [{'text': 'ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้\n---\n**Q: Watch S3 Ultra ต่างจาก Watch S3 Pro ยังไงบ้างครับ?**\nA: S3 Ultra แตกต่างจาก S3 Pro ในหลายด้านครับ ได้แก่ (1) ตัวเรือนไทเทเนียม เบากว่าสแตนเลสของ S3 Pro, (2) กันน้ำ 100 เมตร พร้อม Dive Mode — S3 Pro กันน้ำ 50 เมตรแต่ไม่มี Dive Mode, (3) GPS แบบ Dual-Band แม่นยำกว่า S3 Pro ที่เป็น Single-Band, (4) หน้าจอใหญ่กว่า 1.9 นิ้ว vs 1.7 นิ้ว, (5) แบตเตอรี่อึดกว่า ทั้งสองรุ่นมี ECG และ NFC Pay เหมือนกัน  \n**Q: Dive Mode ใช้ดำน้ำได้ลึกแค่ไหนครับ?**\nA: Dive Mode ของ S3 Ultra รองรับการดำน้ำสูงสุด 40 เมตร (ลึกกว่านั้นนาฬิกาจะไม่รับประกันความถูกต้องของข้อมูลและอาจเกิดความเสียหายได้) ในระหว่างดำน้ำจะแสดงผลความลึก อุณหภูมิน้ำ และเวลาดำน้ำ แต่ขอแนะนำว่าไม่ควรดำน้ำในน้ำร้อน น้ำพุร้อน หรือน้ำทะเลที่มีแรงดัน เพราะอาจส่งผลต่อซีลกันน้ำได้  \n**Q: ECG ใช้งานได้ไหม ถ้าใช้ Android ทั่วไป (ไม่ใช่ FahMai)?**\nA: ได้ครับ ฟังก์ชัน ECG รองรับสมาร์ทโฟน Android 8.0 ขึ้นไปที่ติดตั้งแอป WongKhoJon Health แต่บางฟีเจอร์เช่น Health Dashboard อาจแสดงผลได้ไม่ครบถ้วนเหมือนกับสมาร์ทโฟน FahMai OS',
#   'source': 'products/WK-SW-001_wongkhojon_watch_s3_ultra.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra)',
#    'Header 2': 'คำถามที่พบบ่อยเกี่ยวกับสินค้านี้'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-002_wongkhojon_watch_s3_pro.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Pro (WongKhoJon Watch S3 Pro) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้\n---\n**Q: Watch S3 Pro มี ECG ไหมครับ? ต่างจาก Watch S3 ยังไง?**\nA: มีครับ Watch S3 Pro มีฟังก์ชัน ECG (คลื่นไฟฟ้าหัวใจ) ครบ นี่คือความแตกต่างหลักจาก Watch S3 (WK-SW-003) ที่ไม่มี ECG ส่วนฟีเจอร์อื่นอย่าง SpO2, GPS, AMOLED, และกันน้ำ 50 เมตร ทั้งสองรุ่นมีเหมือนกัน ถ้าต้องการ ECG ต้องเลือก S3 Pro หรือสูงกว่า  \n**Q: ว่ายน้ำได้ไหมคะ? ดำน้ำได้ด้วยไหม?**\nA: ว่ายน้ำได้สบายเลยค่ะ กันน้ำ 5 ATM (50 เมตร) รองรับว่ายน้ำในสระและทะเล แต่ไม่มีโหมด Dive Mode สำหรับการดำน้ำลึก ถ้าต้องการ Dive Mode แนะนำ Watch S3 Ultra (WK-SW-001) ที่กันน้ำ 10 ATM และมีโหมดเฉพาะสำหรับการดำน้ำ  \n**Q: NFC Pay ใช้ชำระเงินได้ที่ไหนบ้างครับ?**\nA: ใช้ได้ที่เครื่อง PoS ที่รองรับการชำระเงินแบบ contactless ผ่านระบบ FahMai Pay ครับ ต้องเชื่อมโยงบัตรหรือบัญชีผ่านแอป WongKhoJon Health ก่อนใช้งาน  \n**Q: ข้อมูล ECG แชร์ให้แพทย์ได้ไหมครับ?**',
#   'source': 'products/WK-SW-002_wongkhojon_watch_s3_pro.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Pro (WongKhoJon Watch S3 Pro)',
#    'Header 2': 'คำถามที่พบบ่อยเกี่ยวกับสินค้านี้'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > รายละเอียดสินค้า\n---\nเมื่อกีฬาและเทคโนโลยีมาบรรจบกัน วงโคจร Watch S3 Ultra คือจุดสูงสุดของสายฟิตเนสและการดำน้ำในรูปแบบนาฬิกาสมาร์ทวอทช์ ตัวเรือนผลิตจากไทเทเนียมเกรดการบินอวกาศ (Grade 5 Titanium) น้ำหนักเบากว่าสแตนเลสทั่วไปถึง 40% แต่แข็งแกร่งกว่าหลายเท่า ให้ความรู้สึกสวมใส่ที่เบาสบายตลอดทั้งวันแม้ระหว่างออกกำลังกายหนัก  \nความโดดเด่นที่สุดของ S3 Ultra คือมาตรฐานกันน้ำระดับ 100 เมตร (10 ATM) พร้อมโหมด Dive Mode ที่รองรับการดำน้ำได้ถึง 40 เมตร บันทึกความลึก ความดัน อุณหภูมิน้ำ และเวลาดำน้ำแบบ real-time แสดงผลบนหน้าจอ AMOLED 1.9 นิ้วที่ยังคงอ่านได้ชัดเจนใต้น้ำ รองรับการดำน้ำทั้งแบบ recreational และ freediving  \nระบบ GPS แบบ Dual-Band (L1+L5) ช่วยให้ติดตามเส้นทางได้แม่นยำกว่า GPS แบบ single-band ถึง 3 เท่า โดยเฉพาะในพื้นที่ที่มีตึกสูงหรือป่าทึบ รองรับดาวเทียม GPS, GLONASS, BeiDou, Galileo พร้อมกัน เหมาะสำหรับทั้งนักวิ่ง นักปั่น นักเดินทาง และนักกีฬากลางแจ้งระดับจริงจัง',
#   'source': 'products/WK-SW-001_wongkhojon_watch_s3_ultra.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra)',
#    'Header 2': 'รายละเอียดสินค้า'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้\n---\n**Q: GPS Dual-Band แตกต่างจาก GPS ธรรมดายังไงคะ?**\nA: GPS แบบ Dual-Band รับสัญญาณจากดาวเทียม 2 ย่านความถี่พร้อมกัน (L1 และ L5) ทำให้ลดการรบกวนจากการสะท้อนสัญญาณอาคารและต้นไม้ได้ดีกว่าครับ ผลลัพธ์คือเส้นทางที่บันทึกได้แม่นยำกว่า ไม่กระโดด เหมาะสำหรับการวิ่งในเมืองหรือเดินป่าที่มีสิ่งกีดขวาง  \n**Q: ชาร์จนานแค่ไหนครับ และสายชาร์จใช้ร่วมกับ Watch S3 Pro ได้ไหม?**\nA: ชาร์จเต็มจาก 0% ใช้เวลาประมาณ 90 นาทีครับ แท่นชาร์จแม่เหล็กของ S3 Ultra ใช้ร่วมกับ Watch S3 Pro ได้เลย เพราะใช้มาตรฐานเดียวกัน',
#   'source': 'products/WK-SW-001_wongkhojon_watch_s3_ultra.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra)',
#    'Header 2': 'คำถามที่พบบ่อยเกี่ยวกับสินค้านี้'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-003_wongkhojon_watch_s3.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 (WongKhoJon Watch S3) > รายละเอียดสินค้า\n---\nสำหรับผู้ที่ต้องการสมาร์ทวอทช์ที่ครบเครื่องในงบประมาณระดับกลาง วงโคจร Watch S3 มอบฟีเจอร์หลักที่จำเป็นครบครัน ทั้งหน้าจอ AMOLED สวยคมชัด GPS ในตัว SpO2 และกันน้ำ 5 ATM ในราคาที่เข้าถึงได้ง่ายกว่า S3 Pro กว่าครึ่ง  \nตัวเรือนอะลูมิเนียมอัลลอยด์เคลือบผิวแบบ anodized ให้ความทนทานและน้ำหนักเบาพร้อมกัน หน้าจอ AMOLED 1.7 นิ้วที่มีความสว่าง 1,000 nits ใช้งานได้แม้กลางแดด สีสันสดใส ประหยัดพลังงาน ทำให้แบตเตอรี่อยู่ได้นานถึง 18 ชั่วโมงในโหมดใช้งานเต็มรูปแบบ หรือสูงสุด 10 วันในโหมดประหยัด  \nGPS single-band รองรับดาวเทียม GPS และ GLONASS ติดตามเส้นทางการออกกำลังกายได้แม่นยำในพื้นที่กลางแจ้ง รองรับโหมดกีฬา 100+ ประเภท ตั้งแต่วิ่ง ปั่น ว่ายน้ำ ไปจนถึงโยคะและพิลาทีส เซ็นเซอร์ SpO2 วัดออกซิเจนในเลือดและแจ้งเตือนเมื่อค่าต่ำกว่าระดับที่กำหนด  \n**หมายเหตุสำคัญ:** Watch S3 ไม่มีฟีเจอร์ ECG และไม่มี NFC Pay ซึ่งเป็นความแตกต่างหลักจาก Watch S3 Pro ผู้ที่ต้องการ ECG หรือการชำระเงินผ่านนาฬิกาควรพิจารณา Watch S3 Pro (WK-SW-002) หรือสูงกว่า  \n---',
#   'source': 'products/WK-SW-003_wongkhojon_watch_s3.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 (WongKhoJon Watch S3)',
#    'Header 2': 'รายละเอียดสินค้า'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > โปรโมชันปัจจุบัน\n---\n**ผ่อน 0% นาน 6 เดือน** ผ่านบัตรเครดิตที่ร่วมรายการ\n(หมดเขต 30 มิถุนายน 2569)  \nตัวอย่าง: ฿14,990 ÷ 6 เดือน = เพียง ฿2,498.33/เดือน  \n---',
#   'source': 'products/WK-SW-001_wongkhojon_watch_s3_ultra.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra)',
#    'Header 2': 'โปรโมชันปัจจุบัน'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-003_wongkhojon_watch_s3.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 (WongKhoJon Watch S3) > คำถามที่พบบ่อยเกี่ยวกับสินค้านี้\n---\n**Q: Watch S3 กับ Watch S3 Pro ต่างกันยังไงครับ ราคาต่างกันเยอะไหม?**\nA: ราคาต่างกัน ฿4,000 ครับ (S3 ฿5,990 vs S3 Pro ฿9,990) ความแตกต่างหลักคือ Watch S3 ไม่มี ECG และไม่มี NFC Pay ส่วน S3 Pro มีทั้งสองอย่าง นอกจากนี้ S3 Pro ใช้ตัวเรือนสแตนเลส (หนักกว่าเล็กน้อยแต่ดูพรีเมียมกว่า) ถ้าไม่ได้ต้องการ ECG หรือจ่ายเงินผ่านนาฬิกา Watch S3 คุ้มค่ามากครับ  \n**Q: Watch S3 มี ECG ไหมคะ?**\nA: ไม่มีค่ะ Watch S3 ไม่มีฟีเจอร์ ECG ถ้าต้องการ ECG ต้องเลือก Watch S3 Pro (WK-SW-002) ขึ้นไป S3 มีแค่ HR และ SpO2 เท่านั้น  \n**Q: โหมดกีฬามีกี่ประเภทครับ?**\nA: รองรับกีฬามากกว่า 100 ประเภทครับ ครอบคลุมกีฬาหลัก เช่น วิ่ง เดิน ปั่นจักรยาน ว่ายน้ำ ไปจนถึงกีฬาในร่ม เช่น โยคะ พิลาทีส เวทเทรนนิง และ HIIT',
#   'source': 'products/WK-SW-003_wongkhojon_watch_s3.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 (WongKhoJon Watch S3)',
#    'Header 2': 'คำถามที่พบบ่อยเกี่ยวกับสินค้านี้'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > สเปคสินค้า\n---\n| รายการ | รายละเอียด |\n|--------|-----------|\n| หน้าจอ | 1.9 นิ้ว AMOLED Always-On Display |\n| ความละเอียดหน้าจอ | 466 × 466 พิกเซล |\n| ความสว่าง | สูงสุด 2,000 nits |\n| วัสดุตัวเรือน | Titanium Grade 5 |\n| กระจกหน้าจอ | Sapphire Crystal |\n| GPS | Dual-Band (L1+L5) — GPS, GLONASS, BeiDou, Galileo |\n| เซ็นเซอร์สุขภาพ | HR ตลอด 24 ชั่วโมง, SpO2, ECG, อุณหภูมิผิวหนัง, HRV |\n| กันน้ำ | 100 เมตร (10 ATM) + Dive Mode (สูงสุด 40 เมตร) |\n| NFC | รองรับ (NFC Pay) |\n| แบตเตอรี่ | สูงสุด 72 ชั่วโมง (โหมดปกติ) / 20 วัน (โหมดประหยัด) |\n| ชาร์จ | Magnetic Wireless Charging |\n| ระบบปฏิบัติการ | WongKhoJon OS 3 |\n| รองรับโทรศัพท์ | FahMai OS 13+, Android 8.0+ |\n| Bluetooth | 5.3 |\n| WiFi | 802.11 b/g/n (2.4GHz) |\n| ขนาด | 47 มม. |\n| น้ำหนักตัวเรือน | 37 กรัม (ไม่รวมสาย) |\n| สาย | Titanium Link / Fluoroelastomer (แล้วแต่รุ่น) |\n| สี | Titanium Black, Titanium Silver, Titanium Desert |  \n---',
#   'source': 'products/WK-SW-001_wongkhojon_watch_s3_ultra.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra)',
#    'Header 2': 'สเปคสินค้า'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-002_wongkhojon_watch_s3_pro.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Pro (WongKhoJon Watch S3 Pro) > รายละเอียดสินค้า\n---\nวงโคจร Watch S3 Pro คือสมาร์ทวอทช์ระดับกลางบนที่ไม่ประนีประนอมในเรื่องสุขภาพและการเชื่อมต่อ ตัวเรือนสแตนเลสสตีลเกรด 316L เคลือบ PVD พร้อมหน้าจอ AMOLED 1.7 นิ้วความสว่าง 1,600 nits อ่านได้ชัดทั้งในร่มและกลางแดด ดีไซน์ที่สมดุลระหว่างความเป็นนาฬิกาพรีเมียมและนาฬิกาฟิตเนสทำให้สวมใส่ได้ทุกโอกาส  \nฟีเจอร์เด่นที่ทำให้ S3 Pro อยู่ในระดับบนของซีรีส์ S3 คือ ECG (Electrocardiogram) หรือการวัดคลื่นไฟฟ้าหัวใจ ที่ช่วยตรวจจับภาวะหัวใจเต้นผิดปกติ (Atrial Fibrillation) ได้จากข้อมือ พร้อมรายงานที่สามารถแชร์ให้แพทย์ได้โดยตรง นอกจากนี้ยังมี SpO2 สำหรับวัดออกซิเจนในเลือด และเซ็นเซอร์วัดความเครียด (HRV) ครบชุด  \nNFC Pay ช่วยให้ชำระเงินได้จากข้อมือโดยไม่ต้องหยิบโทรศัพท์ รองรับระบบ FahMai Pay ที่เครื่องรับที่สนับสนุน GPS แบบ single-band รองรับดาวเทียม GPS, GLONASS, BeiDou ให้ความแม่นยำเพียงพอสำหรับการออกกำลังกายทั่วไปทั้งการวิ่ง ปั่นจักรยาน ว่ายน้ำ และเดินป่า มาตรฐานกันน้ำ 5 ATM (50 เมตร) รองรับว่ายน้ำในสระและทะเลได้สบาย  \n---',
#   'source': 'products/WK-SW-002_wongkhojon_watch_s3_pro.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Pro (WongKhoJon Watch S3 Pro)',
#    'Header 2': 'รายละเอียดสินค้า'}},
#  {'text': 'ไฟล์อ้างอิง: products/WK-SW-001_wongkhojon_watch_s3_ultra.md\nหัวข้อที่เกี่ยวข้อง: วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra) > ความเข้ากันได้\n---\n- **สมาร์ทโฟน:** FahMai OS 13 ขึ้นไป และ Android 8.0 ขึ้นไป ผ่านแอป WongKhoJon Health\n- **ไม่รองรับ:** ระบบปฏิบัติการอื่นนอกจาก FahMai OS และ Android\n- **สาย:** รองรับสายวงโคจรขนาด 22 มม. ทุกรุ่น รวมถึงสายของบุคคลที่สามในขนาดเดียวกัน\n- **NFC Pay:** รองรับการชำระเงินผ่าน NFC ที่เครื่องรับรองรับระบบ FahMai Pay  \n---',
#   'source': 'products/WK-SW-001_wongkhojon_watch_s3_ultra.md',
#   'metadata': {'Header 1': 'วงโคจร Watch S3 Ultra (WongKhoJon Watch S3 Ultra)',
#    'Header 2': 'ความเข้ากันได้'}}]

# %% [markdown]
# ### 1.6 Run All Questions (Dense)
#
# Loop through questions, retrieve, generate, and collect predictions.

# %%
import time
import pandas as pd

# ── 1. Query Expansion ──────────────────────────────────────
def expand_query(question):
    resp = ask_llm([{"role": "user", "content":
        f"จงเขียนคำค้นหา 3 แบบที่ต่างกันสำหรับคำถามนี้ คั่นด้วย | : {question}"}])
    time.sleep(0.3)
    if resp is None:
        return [question]
    return [question] + resp.split("|")[:2]


# ── 2. Rerank ────────────────────────────────────────────────
def rerank(query, candidate_chunks, top_n=5):
    pairs = [(query, c["text"][:256]) for c in candidate_chunks]
    scores = cross_encoder.predict(pairs)
    ranked = sorted(zip(scores, candidate_chunks), reverse=True)
    return [chunk for _, chunk in ranked[:top_n]]


# ── 3. Hybrid Retrieve Chunks (รวมทุกอย่าง) ─────────────────
def hybrid_retrieve_chunks(query):
    queries = expand_query(query)

    combined_scores = np.zeros(len(chunks))
    for q in queries:
        idx, scores = hybrid_retrieve(q, chunk_embeddings, k=20)
        for i, s in zip(idx, scores):
            combined_scores[i] += s

    # RRF ดึง 20 candidates
    top_idx = np.argsort(combined_scores)[::-1][:20]
    candidates = [chunks[i] for i in top_idx]

    # Cross-encoder คัดเหลือ 5
    return rerank(query, candidates, top_n=5)

# 2. ฟังก์ชันหลักสำหรับรัน Pipeline
def run_pipeline(questions_list, retrieve_fn, label="hybrid"):
    """Run retrieval + LLM on all questions. Returns predictions dict."""
    predictions = {}

    print(f"🚀 เริ่มรันโมเดลด้วยระบบ: {label} ...")

    for i, q in enumerate(questions_list):
        # 1. ค้นหาเอกสารด้วย Hybrid Search
        retrieved_chunks = retrieve_fn(q["question"])

        # 2. ประกอบร่าง Prompt
        prompt = build_rag_prompt(q["question"], q["choices"], retrieved_chunks)

        # 3. ส่งให้ ThaiLLM คิดและตอบ
        raw = ask_llm([
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": prompt},
        ])

        # 4. สกัดคำตอบ
        pred = parse_answer(raw)

        # Fallback: ถ้า AI รวนจนตอบไม่ตรงฟอร์แมต ให้เดาข้อ 9 (ไม่มีข้อมูล) หรือข้อ 1 ไปก่อน
        # ในที่นี้แนะนำให้เดาข้อ 9 ปลอดภัยกว่าการเดาข้อ 1 เพราะถ้าหาไม่เจอมักจะแปลว่าไม่มีข้อมูล
        if pred is None:
            pred = 9
            print(f"  ⚠️ Q{q['id']:>3}: Parse failed, using fallback (9)")

        predictions[q["id"]] = pred

        print(f"  ✅ Q{q['id']:>3}: pred={predictions[q['id']]}")

        # พักเบรกเล็กน้อย ป้องกัน Rate Limit จาก API
        time.sleep(0.3)

    print(f"\n🎉 {label}: ตอบคำถามเสร็จสิ้นทั้งหมด {len(predictions)} ข้อ")
    return predictions

# ==========================================
# 3. เริ่มรันจริงกับคำถามทั้งหมด (สมมติว่าตัวแปร questions มีครบ 100 ข้อ)
# ==========================================
# รันเลย!
hybrid_preds = run_pipeline(questions, hybrid_retrieve_chunks, label="Hybrid-RAG")

# ==========================================
# 4. เซฟผลลัพธ์เป็นไฟล์ submission.csv เพื่อส่ง Kaggle / ระบบตรวจ
# ==========================================
submission_df = pd.DataFrame({
    "id": list(hybrid_preds.keys()),
    "answer": list(hybrid_preds.values())
})

# บันทึกเป็นไฟล์ CSV
submission_df.to_csv("submission.csv", index=False)
print("\n💾 บันทึกไฟล์ submission.csv เรียบร้อยแล้ว!")
